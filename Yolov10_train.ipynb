# %% [markdown]
# <a href="https://colab.research.google.com/github/dragonrider17489/Apple_pick/blob/main/Yolov10_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Jun 25 10:32:49 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# !pip install -q roboflow
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 45.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.0 MB/s eta 0:00:00

# %%
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt
# Out:
# --2024-06-25 10:34:48--  https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt [following]
# --2024-06-25 10:34:48--  https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !yolo task=detect mode=train epochs=25 batch=32 plots=True \
model='/content/-q/yolov10n.pt' \
data='/content/drive/MyDrive/applepick_v2/data/apple_orange.yaml'
# Out:
# New https://pypi.org/project/ultralytics/8.2.42 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    R_curve.png		val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		val_batch0_pred.jpg
# confusion_matrix.png				    results.png		val_batch1_labels.jpg
# events.out.tfevents.1719311714.03ee969905f4.1154.0  train_batch0.jpg	val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2.jpg	val_batch2_pred.jpg
# labels.jpg					    train_batch960.jpg	weights
# P_curve.png					    train_batch961.jpg
# PR_curve.png					    train_batch962.jpg

# %%
# !zip -r yolov10_apple.zip runs/detect/train
# Out:
# updating: runs/detect/train/ (stored 0%)
# updating: runs/detect/train/results.png (deflated 9%)
# updating: runs/detect/train/labels_correlogram.jpg (deflated 30%)
# updating: runs/detect/train/val_batch0_labels.jpg (deflated 6%)
# updating: runs/detect/train/R_curve.png (deflated 15%)
# updating: runs/detect/train/results.csv (deflated 84%)
# updating: runs/detect/train/train_batch961.jpg (deflated 4%)
# updating: runs/detect/train/val_batch0_pred.jpg (deflated 5%)
# updating: runs/detect/train/weights/ (stored 0%)
# updating: runs/detect/train/weights/last.pt (deflated 10%)
# updating: runs/detect/train/weights/best.pt (deflated 10%)
# updating: runs/detect/train/confusion_matrix.png (deflated 35%)
# updating: runs/detect/train/val_batch1_pred.jpg (deflated 4%)
# updating: runs/detect/train/events.out.tfevents.1719311714.03ee969905f4.1154.0 (deflated 92%)
# updating: runs/detect/train/train_batch962.jpg (deflated 6%)
# updating: runs/detect/train/F1_curve.png (deflated 14%)
# ...

# %%
from google.colab import files

# Replace 'runs/detect/train.zip' with the path to your zipped folder
files.download('yolov10_apple.zip')

# %%
# !yolo task=detect mode=predict conf=0.25 save=True \
model='/content/drive/MyDrive/applepick_v2/Research_paper/yolov10_apple/runs/detect/train/weights/best.pt' \
source='/content/drive/MyDrive/applepick_v2/Research_paper/Fruit-on-a-Mature-Apple-Tree.jpg'
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2695196 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 /content/drive/MyDrive/applepick_v2/Research_paper/Fruit-on-a-Mature-Apple-Tree.jpg: 448x640 9 apples, 132.4ms
# Speed: 5.0ms preprocess, 132.4ms inference, 433.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/predict/Fruit-on-a-Mature-Apple-Tree.jpg', height=500)
